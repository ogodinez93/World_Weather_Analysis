# %%
import os

# %%
# this is to import config
import sys
sys.path.append(os.path.join(os.path.dirname(sys.path[0])))

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the time module.
import time

# TO MAKE AN API CALL
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#3. Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them (lat_lngs) with the zip() function
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# unpack lat_lngs zip object into a list.
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list using enumerate() method.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descp = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Descp": city_weather_descp})
                          #"Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

len(cities)

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | taoudenni
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | alghero
# Processing Record 6 of Set 1 | rundu
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | saint george
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | muhororo
# Processing Record 11 of Set 1 | cacapava do sul
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | hovd
# Processing Record 15 of Set 1 | surman
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | montrose
# Processing Record 18 of Set 1 | ovsyanka
# Processing Record 19 of Set 1 | sayyan
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | abu dhabi
# Processing Record 23 of Set 1 | tolbazy
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | magnitogorsk
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | podor
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | victoria
# Processing Record 34 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | mehamn
# Processing Record 38 of Set 1 | nanortalik
# Processing Record 39 of Set 1 | mahebourg
# Processing Record 40 of Set 1 | felanitx
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | sechura
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | marsa matruh
# Processing Record 45 of Set 1 | esqueda
# Processing Record 46 of Set 1 | taltal
# Processing Record 47 of Set 1 | ko samui
# Processing Record 48 of Set 1 | mandan
# Processing Record 49 of Set 1 | sarankhola
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 1 of Set 2 | lavrentiya
# Processing Record 2 of Set 2 | pavlogradka
# Processing Record 3 of Set 2 | kandrian
# Processing Record 4 of Set 2 | nsanje
# Processing Record 5 of Set 2 | faanui
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | baran
# Processing Record 10 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 11 of Set 2 | marinette
# Processing Record 12 of Set 2 | tasiilaq
# Processing Record 13 of Set 2 | le port
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | la ronge
# Processing Record 16 of Set 2 | berdigestyakh
# Processing Record 17 of Set 2 | kota belud
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | aden
# Processing Record 20 of Set 2 | neyshabur
# Processing Record 21 of Set 2 | vila franca do campo
# Processing Record 22 of Set 2 | codrington
# Processing Record 23 of Set 2 | ketchikan
# Processing Record 24 of Set 2 | souillac
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | butaritari
# Processing Record 27 of Set 2 | hofn
# Processing Record 28 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 2 | luderitz
# Processing Record 30 of Set 2 | nouadhibou
# Processing Record 31 of Set 2 | fredericton
# Processing Record 32 of Set 2 | ekhabi
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | bonavista
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | herat
# Processing Record 38 of Set 2 | sorland
# Processing Record 39 of Set 2 | port elizabeth
# Processing Record 40 of Set 2 | longyearbyen
# Processing Record 41 of Set 2 | esmeraldas
# Processing Record 42 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 2 | pevek
# Processing Record 44 of Set 2 | yabassi
# Processing Record 45 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 2 | shenjiamen
# Processing Record 47 of Set 2 | hasaki
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | kavaratti
# Processing Record 50 of Set 2 | necochea
# Processing Record 1 of Set 3 | airai
# Processing Record 2 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 3 | kushalgarh
# Processing Record 4 of Set 3 | whitecourt
# Processing Record 5 of Set 3 | sao joao da barra
# Processing Record 6 of Set 3 | quelimane
# Processing Record 7 of Set 3 | ostrovnoy
# Processing Record 8 of Set 3 | hamilton
# Processing Record 9 of Set 3 | pangnirtung
# Processing Record 10 of Set 3 | tabou
# Processing Record 11 of Set 3 | karratha
# Processing Record 12 of Set 3 | carnarvon
# Processing Record 13 of Set 3 | norman wells
# Processing Record 14 of Set 3 | coihaique
# Processing Record 15 of Set 3 | bengkulu
# Processing Record 16 of Set 3 | the valley
# Processing Record 17 of Set 3 | fairbanks
# Processing Record 18 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 19 of Set 3 | doha
# Processing Record 20 of Set 3 | abu kamal
# Processing Record 21 of Set 3 | margate
# Processing Record 22 of Set 3 | gainesville
# Processing Record 23 of Set 3 | saint-joseph
# Processing Record 24 of Set 3 | geraldton
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 3 | san felipe
# Processing Record 28 of Set 3 | hay river
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | mount isa
# Processing Record 31 of Set 3 | iqaluit
# Processing Record 32 of Set 3 | killeen
# Processing Record 33 of Set 3 | ancud
# Processing Record 34 of Set 3 | ambulu
# Processing Record 35 of Set 3 | halifax
# Processing Record 36 of Set 3 | bara
# Processing Record 37 of Set 3 | catalina
# Processing Record 38 of Set 3 | suining
# Processing Record 39 of Set 3 | sawtell
# Processing Record 40 of Set 3 | gigmoto
# Processing Record 41 of Set 3 | upernavik
# Processing Record 42 of Set 3 | acarau
# Processing Record 43 of Set 3 | cape town
# Processing Record 44 of Set 3 | saint-georges
# Processing Record 45 of Set 3 | clyde river
# Processing Record 46 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 47 of Set 3 | dongsheng
# Processing Record 48 of Set 3 | aketi
# Processing Record 49 of Set 3 | aleksandrovskoye
# Processing Record 50 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 4 | quatre cocos
# Processing Record 2 of Set 4 | lilongwe
# Processing Record 3 of Set 4 | tiksi
# Processing Record 4 of Set 4 | bandarbeyla
# Processing Record 5 of Set 4 | tura
# Processing Record 6 of Set 4 | amga
# Processing Record 7 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 4 | manta
# Processing Record 9 of Set 4 | bambous virieux
# Processing Record 10 of Set 4 | amambai
# Processing Record 11 of Set 4 | udomlya
# Processing Record 12 of Set 4 | camana
# Processing Record 13 of Set 4 | mar del plata
# Processing Record 14 of Set 4 | buala
# Processing Record 15 of Set 4 | qiongshan
# Processing Record 16 of Set 4 | jamestown
# Processing Record 17 of Set 4 | ponot
# Processing Record 18 of Set 4 | filadelfia
# Processing Record 19 of Set 4 | georgetown
# Processing Record 20 of Set 4 | bredasdorp
# Processing Record 21 of Set 4 | hermanus
# Processing Record 22 of Set 4 | gela
# Processing Record 23 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 4 | saint-philippe
# Processing Record 25 of Set 4 | barrow
# Processing Record 26 of Set 4 | goderich
# Processing Record 27 of Set 4 | toora-khem
# Processing Record 28 of Set 4 | zhezkazgan
# Processing Record 29 of Set 4 | kailua
# Processing Record 30 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 4 | uk
# City not found. Skipping...
# Processing Record 32 of Set 4 | peniche
# Processing Record 33 of Set 4 | tuktoyaktuk
# Processing Record 34 of Set 4 | te anau
# Processing Record 35 of Set 4 | celestun
# Processing Record 36 of Set 4 | jackson
# Processing Record 37 of Set 4 | ust-kuyga
# Processing Record 38 of Set 4 | george town
# Processing Record 39 of Set 4 | gomel
# Processing Record 40 of Set 4 | cabo san lucas
# Processing Record 41 of Set 4 | marsh harbour
# Processing Record 42 of Set 4 | talnakh
# Processing Record 43 of Set 4 | port hedland
# Processing Record 44 of Set 4 | san cristobal
# Processing Record 45 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 4 | ponta do sol
# Processing Record 48 of Set 4 | ahuimanu
# Processing Record 49 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 5 | maldonado
# Processing Record 2 of Set 5 | pontianak
# Processing Record 3 of Set 5 | thunder bay
# Processing Record 4 of Set 5 | rio grande
# Processing Record 5 of Set 5 | nalut
# Processing Record 6 of Set 5 | floriano
# Processing Record 7 of Set 5 | okhotsk
# Processing Record 8 of Set 5 | chokurdakh
# Processing Record 9 of Set 5 | abha
# Processing Record 10 of Set 5 | whitehorse
# Processing Record 11 of Set 5 | tha chang
# Processing Record 12 of Set 5 | dmytrivka
# Processing Record 13 of Set 5 | kapurthala
# Processing Record 14 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 5 | nioro
# Processing Record 16 of Set 5 | bodden town
# Processing Record 17 of Set 5 | flinders
# Processing Record 18 of Set 5 | port blair
# Processing Record 19 of Set 5 | sur
# Processing Record 20 of Set 5 | salalah
# Processing Record 21 of Set 5 | kifri
# Processing Record 22 of Set 5 | kahului
# Processing Record 23 of Set 5 | novo aripuana
# Processing Record 24 of Set 5 | cockburn town
# Processing Record 25 of Set 5 | pimenta bueno
# Processing Record 26 of Set 5 | cayenne
# Processing Record 27 of Set 5 | sobolevo
# Processing Record 28 of Set 5 | san andres
# Processing Record 29 of Set 5 | kimbe
# Processing Record 30 of Set 5 | sisimiut
# Processing Record 31 of Set 5 | paamiut
# Processing Record 32 of Set 5 | gat
# Processing Record 33 of Set 5 | pangoa
# Processing Record 34 of Set 5 | ukiah
# Processing Record 35 of Set 5 | nabire
# Processing Record 36 of Set 5 | lincoln
# Processing Record 37 of Set 5 | kiruna
# Processing Record 38 of Set 5 | lebu
# Processing Record 39 of Set 5 | barra patuca
# Processing Record 40 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 41 of Set 5 | aklavik
# Processing Record 42 of Set 5 | acapulco
# Processing Record 43 of Set 5 | mayumba
# Processing Record 44 of Set 5 | kargasok
# Processing Record 45 of Set 5 | abu samrah
# Processing Record 46 of Set 5 | kununurra
# Processing Record 47 of Set 5 | faya
# Processing Record 48 of Set 5 | hilton head island
# Processing Record 49 of Set 5 | tessalit
# Processing Record 50 of Set 5 | college
# Processing Record 1 of Set 6 | komsomolskiy
# Processing Record 2 of Set 6 | cap malheureux
# Processing Record 3 of Set 6 | sao raimundo nonato
# Processing Record 4 of Set 6 | micco
# Processing Record 5 of Set 6 | metro
# Processing Record 6 of Set 6 | dingle
# Processing Record 7 of Set 6 | kingaroy
# Processing Record 8 of Set 6 | nizhnevartovsk
# Processing Record 9 of Set 6 | jalu
# Processing Record 10 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 11 of Set 6 | uttarkashi
# Processing Record 12 of Set 6 | chuy
# Processing Record 13 of Set 6 | nantucket
# Processing Record 14 of Set 6 | teya
# Processing Record 15 of Set 6 | porto novo
# Processing Record 16 of Set 6 | kapit
# Processing Record 17 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 18 of Set 6 | erenhot
# Processing Record 19 of Set 6 | marabba
# Processing Record 20 of Set 6 | vestmannaeyjar
# Processing Record 21 of Set 6 | wukari
# Processing Record 22 of Set 6 | katsuura
# Processing Record 23 of Set 6 | lata
# Processing Record 24 of Set 6 | chicama
# Processing Record 25 of Set 6 | saldanha
# Processing Record 26 of Set 6 | zawiercie
# Processing Record 27 of Set 6 | hailar
# Processing Record 28 of Set 6 | san patricio
# Processing Record 29 of Set 6 | esperance
# Processing Record 30 of Set 6 | hobyo
# Processing Record 31 of Set 6 | nome
# Processing Record 32 of Set 6 | trinidad
# Processing Record 33 of Set 6 | ekibastuz
# Processing Record 34 of Set 6 | palana
# Processing Record 35 of Set 6 | qaanaaq
# Processing Record 36 of Set 6 | swan hill
# Processing Record 37 of Set 6 | haapiti
# Processing Record 38 of Set 6 | bac lieu
# Processing Record 39 of Set 6 | yar-sale
# Processing Record 40 of Set 6 | half moon bay
# Processing Record 41 of Set 6 | pudozh
# Processing Record 42 of Set 6 | kabinda
# Processing Record 43 of Set 6 | senneterre
# Processing Record 44 of Set 6 | kaniama
# Processing Record 45 of Set 6 | gagra
# Processing Record 46 of Set 6 | pangody
# Processing Record 47 of Set 6 | port hardy
# Processing Record 48 of Set 6 | vila do maio
# Processing Record 49 of Set 6 | dudinka
# Processing Record 50 of Set 6 | mutsu
# Processing Record 1 of Set 7 | xiongzhou
# Processing Record 2 of Set 7 | ust-maya
# Processing Record 3 of Set 7 | boueni
# Processing Record 4 of Set 7 | litovko
# Processing Record 5 of Set 7 | tarakan
# Processing Record 6 of Set 7 | kalmunai
# Processing Record 7 of Set 7 | lompoc
# Processing Record 8 of Set 7 | muros
# Processing Record 9 of Set 7 | marzuq
# Processing Record 10 of Set 7 | bathsheba
# Processing Record 11 of Set 7 | havelock
# Processing Record 12 of Set 7 | huarmey
# Processing Record 13 of Set 7 | evensk
# Processing Record 14 of Set 7 | puerto escondido
# Processing Record 15 of Set 7 | leningradskiy
# Processing Record 16 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 17 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 18 of Set 7 | muncar
# Processing Record 19 of Set 7 | henties bay
# Processing Record 20 of Set 7 | ryki
# Processing Record 21 of Set 7 | virginia
# Processing Record 22 of Set 7 | salinopolis
# Processing Record 23 of Set 7 | constitucion
# Processing Record 24 of Set 7 | anchorage
# Processing Record 25 of Set 7 | sambava
# Processing Record 26 of Set 7 | balsta
# Processing Record 27 of Set 7 | rawson
# Processing Record 28 of Set 7 | kotelnich
# Processing Record 29 of Set 7 | guerrero negro
# Processing Record 30 of Set 7 | waipawa
# Processing Record 31 of Set 7 | broken hill
# Processing Record 32 of Set 7 | kudahuvadhoo
# Processing Record 33 of Set 7 | berezovyy
# Processing Record 34 of Set 7 | visnes
# Processing Record 35 of Set 7 | ballina
# Processing Record 36 of Set 7 | hambantota
# Processing Record 37 of Set 7 | ithaca
# Processing Record 38 of Set 7 | rupert
# Processing Record 39 of Set 7 | tual
# Processing Record 40 of Set 7 | port lincoln
# Processing Record 41 of Set 7 | shingu
# Processing Record 42 of Set 7 | lazaro cardenas
# Processing Record 43 of Set 7 | katobu
# Processing Record 44 of Set 7 | sijunjung
# Processing Record 45 of Set 7 | wuda
# Processing Record 46 of Set 7 | bafata
# Processing Record 47 of Set 7 | cherskiy
# Processing Record 48 of Set 7 | ventspils
# Processing Record 49 of Set 7 | axim
# Processing Record 50 of Set 7 | lensk
# Processing Record 1 of Set 8 | kaitangata
# Processing Record 2 of Set 8 | sao jose da coroa grande
# Processing Record 3 of Set 8 | srednekolymsk
# Processing Record 4 of Set 8 | anadyr
# Processing Record 5 of Set 8 | tateyama
# Processing Record 6 of Set 8 | san cosme y damian
# Processing Record 7 of Set 8 | yining
# Processing Record 8 of Set 8 | quiruvilca
# Processing Record 9 of Set 8 | log
# Processing Record 10 of Set 8 | kamina
# Processing Record 11 of Set 8 | bago
# Processing Record 12 of Set 8 | artyom
# Processing Record 13 of Set 8 | sa kaeo
# Processing Record 14 of Set 8 | antonina
# Processing Record 15 of Set 8 | soe
# Processing Record 16 of Set 8 | paz de ariporo
# City not found. Skipping...
# Processing Record 17 of Set 8 | thinadhoo
# Processing Record 18 of Set 8 | murray bridge
# Processing Record 19 of Set 8 | akdepe
# Processing Record 20 of Set 8 | wanderlandia
# City not found. Skipping...
# Processing Record 21 of Set 8 | chapais
# Processing Record 22 of Set 8 | kangalassy
# Processing Record 23 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 24 of Set 8 | tanout
# Processing Record 25 of Set 8 | san jose
# Processing Record 26 of Set 8 | lorengau
# Processing Record 27 of Set 8 | touros
# Processing Record 28 of Set 8 | vostok
# Processing Record 29 of Set 8 | borba
# Processing Record 30 of Set 8 | athabasca
# Processing Record 31 of Set 8 | tapaua
# City not found. Skipping...
# Processing Record 32 of Set 8 | champerico
# Processing Record 33 of Set 8 | praia da vitoria
# Processing Record 34 of Set 8 | parana
# Processing Record 35 of Set 8 | dunedin
# Processing Record 36 of Set 8 | takoradi
# Processing Record 37 of Set 8 | parintins
# Processing Record 38 of Set 8 | seydi
# Processing Record 39 of Set 8 | huntsville
# Processing Record 40 of Set 8 | port augusta
# Processing Record 41 of Set 8 | beringovskiy
# Processing Record 42 of Set 8 | lleida
# Processing Record 43 of Set 8 | concepcion del oro
# Processing Record 44 of Set 8 | krutinka
# Processing Record 45 of Set 8 | westport
# Processing Record 46 of Set 8 | pacific grove
# Processing Record 47 of Set 8 | idenao
# Processing Record 48 of Set 8 | ormara
# Processing Record 49 of Set 8 | jundia
# Processing Record 50 of Set 8 | tumen
# Processing Record 1 of Set 9 | deputatskiy
# Processing Record 2 of Set 9 | kartaly
# Processing Record 3 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 9 | ngunguru
# Processing Record 5 of Set 9 | clovis
# Processing Record 6 of Set 9 | hudiksvall
# Processing Record 7 of Set 9 | tiarei
# Processing Record 8 of Set 9 | mahibadhoo
# Processing Record 9 of Set 9 | haimen
# Processing Record 10 of Set 9 | fortuna
# Processing Record 11 of Set 9 | kamenka
# Processing Record 12 of Set 9 | maple creek
# Processing Record 13 of Set 9 | qasigiannguit
# Processing Record 14 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 9 | kosh-agach
# Processing Record 16 of Set 9 | paraguari
# Processing Record 17 of Set 9 | pisco
# Processing Record 18 of Set 9 | bilibino
# Processing Record 19 of Set 9 | lingao
# Processing Record 20 of Set 9 | aykino
# Processing Record 21 of Set 9 | alamosa
# Processing Record 22 of Set 9 | bumba
# Processing Record 23 of Set 9 | guatire
# Processing Record 24 of Set 9 | asfi
# Processing Record 25 of Set 9 | namtsy
# Processing Record 26 of Set 9 | baykit
# Processing Record 27 of Set 9 | oytal
# Processing Record 28 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 9 | port arthur
# Processing Record 30 of Set 9 | brufut
# Processing Record 31 of Set 9 | dolores
# Processing Record 32 of Set 9 | powell
# Processing Record 33 of Set 9 | asau
# Processing Record 34 of Set 9 | kharan
# Processing Record 35 of Set 9 | lethem
# Processing Record 36 of Set 9 | utica
# Processing Record 37 of Set 9 | palauig
# Processing Record 38 of Set 9 | vagay
# Processing Record 39 of Set 9 | ponta delgada
# Processing Record 40 of Set 9 | isangel
# Processing Record 41 of Set 9 | svetlaya
# Processing Record 42 of Set 9 | vanimo
# Processing Record 43 of Set 9 | east london
# Processing Record 44 of Set 9 | alofi
# Processing Record 45 of Set 9 | keti bandar
# Processing Record 46 of Set 9 | kruisfontein
# Processing Record 47 of Set 9 | skeldon
# Processing Record 48 of Set 9 | cidreira
# Processing Record 49 of Set 9 | adelaide
# Processing Record 50 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 10 | qui nhon
# Processing Record 2 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 3 of Set 10 | portland
# Processing Record 4 of Set 10 | tripoli
# Processing Record 5 of Set 10 | zhob
# Processing Record 6 of Set 10 | tuatapere
# Processing Record 7 of Set 10 | sangar
# Processing Record 8 of Set 10 | lalganj
# Processing Record 9 of Set 10 | belyy yar
# Processing Record 10 of Set 10 | key west
# Processing Record 11 of Set 10 | severo-kurilsk
# Processing Record 12 of Set 10 | rafaela
# Processing Record 13 of Set 10 | tacuati
# Processing Record 14 of Set 10 | san jeronimo
# Processing Record 15 of Set 10 | kibaya
# Processing Record 16 of Set 10 | mount gambier
# Processing Record 17 of Set 10 | san andres del rabanedo
# Processing Record 18 of Set 10 | los llanos de aridane
# Processing Record 19 of Set 10 | ciudad bolivar
# Processing Record 20 of Set 10 | okha
# Processing Record 21 of Set 10 | karoi
# Processing Record 22 of Set 10 | puerto maldonado
# Processing Record 23 of Set 10 | andenes
# Processing Record 24 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 25 of Set 10 | beloha
# Processing Record 26 of Set 10 | viedma
# Processing Record 27 of Set 10 | gidam
# Processing Record 28 of Set 10 | urumqi
# Processing Record 29 of Set 10 | alice springs
# Processing Record 30 of Set 10 | yenagoa
# Processing Record 31 of Set 10 | port-cartier
# Processing Record 32 of Set 10 | west bay
# Processing Record 33 of Set 10 | beboto
# Processing Record 34 of Set 10 | sosnytsya
# Processing Record 35 of Set 10 | honiton
# Processing Record 36 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 37 of Set 10 | vanavara
# Processing Record 38 of Set 10 | namibe
# Processing Record 39 of Set 10 | kahama
# Processing Record 40 of Set 10 | wheeling
# Processing Record 41 of Set 10 | camacari
# Processing Record 42 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 43 of Set 10 | bobrovka
# Processing Record 44 of Set 10 | caravelas
# Processing Record 45 of Set 10 | sioux lookout
# Processing Record 46 of Set 10 | mayo
# Processing Record 47 of Set 10 | yakeshi
# Processing Record 48 of Set 10 | manzanillo
# Processing Record 49 of Set 10 | altagracia de orituco
# Processing Record 50 of Set 10 | havoysund
# Processing Record 1 of Set 11 | urfa
# City not found. Skipping...
# Processing Record 2 of Set 11 | emerald
# Processing Record 3 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 4 of Set 11 | pucallpa
# Processing Record 5 of Set 11 | tagusao
# Processing Record 6 of Set 11 | narsaq
# Processing Record 7 of Set 11 | talas
# Processing Record 8 of Set 11 | miri
# Processing Record 9 of Set 11 | saint-augustin
# Processing Record 10 of Set 11 | wadi maliz
# Processing Record 11 of Set 11 | pinsk
# Processing Record 12 of Set 11 | belmonte
# Processing Record 13 of Set 11 | kavieng
# Processing Record 14 of Set 11 | grand gaube
# Processing Record 15 of Set 11 | menongue
# Processing Record 16 of Set 11 | okakarara
# Processing Record 17 of Set 11 | santa rosa
# Processing Record 18 of Set 11 | eirunepe
# Processing Record 19 of Set 11 | betioky
# Processing Record 20 of Set 11 | khandbari
# Processing Record 21 of Set 11 | coahuayana
# Processing Record 22 of Set 11 | sun valley
# Processing Record 23 of Set 11 | batemans bay
# Processing Record 24 of Set 11 | formello
# Processing Record 25 of Set 11 | sinnamary
# Processing Record 26 of Set 11 | nouakchott
# Processing Record 27 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 28 of Set 11 | sredniy ikorets
# Processing Record 29 of Set 11 | ca mau
# Processing Record 30 of Set 11 | veraval
# Processing Record 31 of Set 11 | manggar
# Processing Record 32 of Set 11 | salinas
# Processing Record 33 of Set 11 | corn island
# Processing Record 34 of Set 11 | najran
# Processing Record 35 of Set 11 | shepetivka
# Processing Record 36 of Set 11 | walvis bay
# Processing Record 37 of Set 11 | balud
# Processing Record 38 of Set 11 | solec kujawski
# Processing Record 39 of Set 11 | mindelo
# Processing Record 40 of Set 11 | sarakhs
# Processing Record 41 of Set 11 | port shepstone
# Processing Record 42 of Set 11 | sao filipe
# Processing Record 43 of Set 11 | hirara
# Processing Record 44 of Set 11 | pandan
# Processing Record 45 of Set 11 | clarence town
# Processing Record 46 of Set 11 | leninskoye
# Processing Record 47 of Set 11 | mpika
# Processing Record 48 of Set 11 | smithers
# Processing Record 49 of Set 11 | north bend
# Processing Record 50 of Set 11 | debre tabor
# Processing Record 1 of Set 12 | zhigansk
# Processing Record 2 of Set 12 | dzhankoy
# Processing Record 3 of Set 12 | tommot
# Processing Record 4 of Set 12 | dori
# Processing Record 5 of Set 12 | mimoso do sul
# Processing Record 6 of Set 12 | chuzhou
# Processing Record 7 of Set 12 | turukhansk
# Processing Record 8 of Set 12 | bud
# Processing Record 9 of Set 12 | sulangan
# Processing Record 10 of Set 12 | micheweni
# Processing Record 11 of Set 12 | palmer
# Processing Record 12 of Set 12 | ordynskoye
# Processing Record 13 of Set 12 | conakry
# Processing Record 14 of Set 12 | port moresby
# Processing Record 15 of Set 12 | severnoye
# Processing Record 16 of Set 12 | norilsk
# Processing Record 17 of Set 12 | atar
# Processing Record 18 of Set 12 | urucara
# Processing Record 19 of Set 12 | berbera
# Processing Record 20 of Set 12 | khandyga
# Processing Record 21 of Set 12 | ginir
# Processing Record 22 of Set 12 | yumen
# Processing Record 23 of Set 12 | oktyabrskoye
# Processing Record 24 of Set 12 | ayan
# Processing Record 25 of Set 12 | chippewa falls
# Processing Record 26 of Set 12 | plainview
# Processing Record 27 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 28 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 12 | alyangula
# Processing Record 30 of Set 12 | villazon
# Processing Record 31 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 12 | hualmay
# Processing Record 33 of Set 12 | pangai
# Processing Record 34 of Set 12 | ust-nera
# Processing Record 35 of Set 12 | sumbawanga
# Processing Record 36 of Set 12 | christchurch
# Processing Record 37 of Set 12 | la primavera
# Processing Record 38 of Set 12 | puerto rondon
# Processing Record 39 of Set 12 | baruun-urt
# Processing Record 40 of Set 12 | madison
# Processing Record 41 of Set 12 | zlitan
# Processing Record 42 of Set 12 | makung
# City not found. Skipping...
# Processing Record 43 of Set 12 | bataipora
# Processing Record 44 of Set 12 | raudeberg
# Processing Record 45 of Set 12 | port-gentil
# Processing Record 46 of Set 12 | tarhunah
# City not found. Skipping...
# Processing Record 47 of Set 12 | rach gia
# Processing Record 48 of Set 12 | manoel urbano
# Processing Record 49 of Set 12 | coquimbo
# Processing Record 50 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 13 | lovec
# City not found. Skipping...
# Processing Record 2 of Set 13 | avera
# Processing Record 3 of Set 13 | ixtapa
# Processing Record 4 of Set 13 | simpang
# Processing Record 5 of Set 13 | atikokan
# Processing Record 6 of Set 13 | twentynine palms
# Processing Record 7 of Set 13 | bunia
# Processing Record 8 of Set 13 | karpogory
# Processing Record 9 of Set 13 | dwarka
# Processing Record 10 of Set 13 | knysna
# Processing Record 11 of Set 13 | zhangye
# Processing Record 12 of Set 13 | gavrilov posad
# Processing Record 13 of Set 13 | rabo de peixe
# Processing Record 14 of Set 13 | sault sainte marie
# Processing Record 15 of Set 13 | isabela
# Processing Record 16 of Set 13 | sweetwater
# Processing Record 17 of Set 13 | cabedelo
# Processing Record 18 of Set 13 | killybegs
# Processing Record 19 of Set 13 | metehara
# City not found. Skipping...
# Processing Record 20 of Set 13 | harper
# Processing Record 21 of Set 13 | bozoum
# Processing Record 22 of Set 13 | dom pedro
# Processing Record 23 of Set 13 | kibre mengist
# Processing Record 24 of Set 13 | yarada
# Processing Record 25 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 13 | tutoia
# Processing Record 27 of Set 13 | karpathos
# Processing Record 28 of Set 13 | qeshm
# Processing Record 29 of Set 13 | port keats
# Processing Record 30 of Set 13 | gogrial
# Processing Record 31 of Set 13 | lahaina
# Processing Record 32 of Set 13 | araguacu
# Processing Record 33 of Set 13 | makueni
# Processing Record 34 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 13 | vila velha
# Processing Record 36 of Set 13 | northam
# Processing Record 37 of Set 13 | bopfingen
# Processing Record 38 of Set 13 | keflavik
# Processing Record 39 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 40 of Set 13 | prieska
# Processing Record 41 of Set 13 | suffolk
# Processing Record 42 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 44 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 13 | saint anthony
# Processing Record 46 of Set 13 | oga
# Processing Record 47 of Set 13 | la seyne-sur-mer
# Processing Record 48 of Set 13 | south lake tahoe
# Processing Record 49 of Set 13 | natal
# Processing Record 50 of Set 13 | warrnambool
# Processing Record 1 of Set 14 | guigue
# Processing Record 2 of Set 14 | japura
# Processing Record 3 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 14 | baracoa
# Processing Record 5 of Set 14 | vardo
# Processing Record 6 of Set 14 | angoram
# Processing Record 7 of Set 14 | santa maria
# Processing Record 8 of Set 14 | husavik
# Processing Record 9 of Set 14 | linjiang
# Processing Record 10 of Set 14 | bolshiye uki
# City not found. Skipping...
# Processing Record 11 of Set 14 | aranos
# Processing Record 12 of Set 14 | mawlaik
# Processing Record 13 of Set 14 | ewa beach
# Processing Record 14 of Set 14 | sandovo
# Processing Record 15 of Set 14 | mareeba
# Processing Record 16 of Set 14 | ucluelet
# Processing Record 17 of Set 14 | keetmanshoop
# Processing Record 18 of Set 14 | santa barbara
# Processing Record 19 of Set 14 | tallahassee
# Processing Record 20 of Set 14 | pangkalanbuun
# Processing Record 21 of Set 14 | albesti-paleologu
# Processing Record 22 of Set 14 | venezuela
# Processing Record 23 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 24 of Set 14 | sekudai
# Processing Record 25 of Set 14 | gizo
# Processing Record 26 of Set 14 | sola
# Processing Record 27 of Set 14 | mayor pablo lagerenza
# Processing Record 28 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 14 | haines junction
# Processing Record 30 of Set 14 | nanlong
# Processing Record 31 of Set 14 | gulu
# Processing Record 32 of Set 14 | padang
# Processing Record 33 of Set 14 | yulara
# Processing Record 34 of Set 14 | lermontovka
# Processing Record 35 of Set 14 | banjar
# Processing Record 36 of Set 14 | saint-pierre
# Processing Record 37 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 14 | ajdabiya
# Processing Record 39 of Set 14 | phenix city
# Processing Record 40 of Set 14 | abonnema
# Processing Record 41 of Set 14 | ikalamavony
# Processing Record 42 of Set 14 | klaksvik
# Processing Record 43 of Set 14 | aguas belas
# Processing Record 44 of Set 14 | morgan city
# Processing Record 45 of Set 14 | wakkanai
# Processing Record 46 of Set 14 | qaqortoq
# Processing Record 47 of Set 14 | pemangkat
# Processing Record 48 of Set 14 | shimanovsk
# Processing Record 49 of Set 14 | san angelo
# Processing Record 50 of Set 14 | kendari
# Processing Record 1 of Set 15 | ushtobe
# Processing Record 2 of Set 15 | marawi
# Processing Record 3 of Set 15 | lagoa
# Processing Record 4 of Set 15 | snezhnogorsk
# Processing Record 5 of Set 15 | rocha
# Processing Record 6 of Set 15 | seabra
# Processing Record 7 of Set 15 | lundazi
# Processing Record 8 of Set 15 | villa bruzual
# Processing Record 9 of Set 15 | aktau
# Processing Record 10 of Set 15 | kaz
# Processing Record 11 of Set 15 | tunxi
# City not found. Skipping...
# Processing Record 12 of Set 15 | maniitsoq
# Processing Record 13 of Set 15 | nizhniy kuranakh
# Processing Record 14 of Set 15 | upata
# Processing Record 15 of Set 15 | mogadishu
# Processing Record 16 of Set 15 | muzhi
# Processing Record 17 of Set 15 | porto belo
# Processing Record 18 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 19 of Set 15 | aksarka
# Processing Record 20 of Set 15 | merauke
# Processing Record 21 of Set 15 | ola
# Processing Record 22 of Set 15 | gorele
# Processing Record 23 of Set 15 | beira
# Processing Record 24 of Set 15 | vao
# Processing Record 25 of Set 15 | moussoro
# Processing Record 26 of Set 15 | loikaw
# Processing Record 27 of Set 15 | roald
# Processing Record 28 of Set 15 | labrea
# Processing Record 29 of Set 15 | riyadh
# Processing Record 30 of Set 15 | pereira barreto
# Processing Record 31 of Set 15 | barcelona
# Processing Record 32 of Set 15 | nicoya
# Processing Record 33 of Set 15 | kourou
# Processing Record 34 of Set 15 | port hawkesbury
# Processing Record 35 of Set 15 | cacu
# Processing Record 36 of Set 15 | kysyl-syr
# Processing Record 37 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 38 of Set 15 | eufaula
# Processing Record 39 of Set 15 | gwadar
# Processing Record 40 of Set 15 | osakarovka
# Processing Record 41 of Set 15 | safaga
# Processing Record 42 of Set 15 | cairns
# Processing Record 43 of Set 15 | miyako
# Processing Record 44 of Set 15 | mahajanga
# Processing Record 45 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 46 of Set 15 | santo antonio do ica
# Processing Record 47 of Set 15 | urengoy
# Processing Record 48 of Set 15 | surt
# Processing Record 49 of Set 15 | inirida
# Processing Record 50 of Set 15 | boppard
# Processing Record 1 of Set 16 | auburn
# Processing Record 2 of Set 16 | dzhusaly
# City not found. Skipping...
# Processing Record 3 of Set 16 | antofagasta
# Processing Record 4 of Set 16 | brits
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           Castro -24.79  -50.01     57.49        87         100       10.78
# 1           Kodiak  57.79 -152.41     35.60        74          90        5.82
# 2        Taoudenni  22.68   -3.98     91.74        11         100       11.10
# 3          Alghero  40.56    8.32     64.40        82          20        5.82
# 4            Rundu -17.93   19.77     89.80        25          80        8.57
# 5           Albany  42.60  -73.97     34.00        88         100        7.27
# 6     Saint George  37.10 -113.58     48.20        31           1        3.56
# 7          Rikitea -23.12 -134.97     75.13        70          66        5.75
# 8         Muhororo   0.94   30.76     63.97        88         100        0.92
# 9  Cacapava Do Sul -30.51  -53.49     65.39        49           0        8.21
#
#   Country    Weather Descp
# 0      BR  overcast clouds
# 1      US  overcast clouds
# 2      ML  overcast clouds
# 3      IT       few clouds
# 4      NA    broken clouds
# 5      US  overcast clouds
# 6      US        clear sky
# 7      PF    broken clouds
# 8      UG  overcast clouds
# 9      BR        clear sky

# %%
# reorder the coloumn
new_column_reorder = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Weather Descp"]

# %%
# assign a new or the same DataFrame with new column order
city_data_df = city_data_df[new_column_reorder]
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Castro      BR -24.79  -50.01     57.49        87         100
# 1           Kodiak      US  57.79 -152.41     35.60        74          90
# 2        Taoudenni      ML  22.68   -3.98     91.74        11         100
# 3          Alghero      IT  40.56    8.32     64.40        82          20
# 4            Rundu      NA -17.93   19.77     89.80        25          80
# 5           Albany      US  42.60  -73.97     34.00        88         100
# 6     Saint George      US  37.10 -113.58     48.20        31           1
# 7          Rikitea      PF -23.12 -134.97     75.13        70          66
# 8         Muhororo      UG   0.94   30.76     63.97        88         100
# 9  Cacapava Do Sul      BR -30.51  -53.49     65.39        49           0
#
#    Wind Speed    Weather Descp
# 0       10.78  overcast clouds
# 1        5.82  overcast clouds
# 2       11.10  overcast clouds
# 3        5.82       few clouds
# 4        8.57    broken clouds
# 5        7.27  overcast clouds
# 6        3.56        clear sky
# 7        5.75    broken clouds
# 8        0.92  overcast clouds
# 9        8.21        clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
